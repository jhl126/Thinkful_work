# %% [markdown]
# # Morning Lecture: ARIMA Modeling

# %%
import pandas as pd
import plotly.express as px

from statsmodels.tsa.ar_model import AR
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX

df = pd.read_csv('/content/drive/My Drive/DSI Month 4/Week 12/Datasets/LA_weather.csv')

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45099 entries, 0 to 45098
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      45099 non-null  datetime64[ns]
#  1   Observed  45099 non-null  float64
#  2   Humidity  45099 non-null  float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 1.0 MB

# %%
df.head()
# Out:
#                  Date    Observed  Humidity
# 0 2012-10-01 13:00:00  291.870000      88.0
# 1 2012-10-01 14:00:00  291.868186      88.0
# 2 2012-10-01 15:00:00  291.862844      88.0
# 3 2012-10-01 16:00:00  291.857503      88.0
# 4 2012-10-01 17:00:00  291.852162      88.0

# %%
def ilinechart(df, x, y, groups=None, title=''):
    fig = px.line(df, x=x, y=y, color=groups, title=title, 
                  template='none').update(layout=dict(title=dict(x=0.5)))
    
    fig.show()

# %%
ilinechart(df, 'Date', 'Observed')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="81219b14-4a1d-470a-a1b5-346ffd5e2b2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("81219b14-4a1d-470a-a1b5-346ffd5e2b2e")) {
#                     Plotly.newPlot(
#                         '81219b14-4a1d-470a-a1b5-346ffd5e2b2e',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Observed=%{y}", "legendgroup": "", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2012-10-01T13:00:00", "2012-10-01T14:00:00", "2012-10-01T15:00:00", "2012-10-01T16:00:00", "2012-10-01T17:00:00", "2012-10-01T18:00:00", "2012-10-01T19:00:00", "2012-10-01T20:00:00", "2012-10-01T21:00:00", "2012-10-01T22:00:00", "2012-10-01T23:00:00", "2012-10-02T00:00:00", "2012-10-02T01:00:00", "2012-10-02T02:00:00", "2012-10-02T03:00:00", "2012-10-02T04:00:00", "2012-10-02T05:00:00", "2012-10-02T06:00:00", "2012-10-02T07:00:00", "2012-10-02T08:00:00", "2012-10-02T09:00:00", "2012-10-02T10:00:00", "2012-10-02T11:00:00", "2012-10-02T12:00:00", "2012-10-02T13:00:00", "2012-10-02T14:00:00", "2012-10-02T15:00:00", "2012-10-02T16:00:00", "2012-10-02T17:00:00", "2012-10-02T18:00:00", "2012-10-02T19:00:00", "2012-10-02T20:00:00", "2012-10-02T21:00:00", "2012-10-02T22:00:00", "2012-10-02T23:00:00", "2012-10-03T00:00:00", "2012-10-03T01:00:00", "2012-10-03T02:00:00", "2012-10-03T03:00:00", "2012-10-03T04:00:00", "2012-10-03T05:00:00", "2012-10-03T06:00:00", "2012-10-03T07:00:00", "2012-10-03T08:00:00", "2012-10-03T09:00:00", "2012-10-03T10:00:00", "2012-10-03T11:00:00", "2012-10-03T12:00:00", "2012-10-03T13:00:00", "2012-10-03T14:00:00", "2012-10-03T15:00:00", "2012-10-03T16:00:00", "2012-10-03T17:00:00", "2012-10-03T18:00:00", "2012-10-03T19:00:00", "2012-10-03T20:00:00", "2012-10-03T21:00:00", "2012-10-03T22:00:00", "2012-10-03T23:00:00", "2012-10-04T00:00:00", "2012-10-04T01:00:00", "2012-10-04T02:00:00", "2012-10-04T03:00:00", "2012-10-04T04:00:00", "2012-10-04T05:00:00", "2012-10-04T06:00:00", "2012-10-04T07:00:00", "2012-10-04T08:00:00", "2012-10-04T09:00:00", "2012-10-04T10:00:00", "2012-10-04T11:00:00", "2012-10-04T12:00:00", "2012-10-04T13:00:00", "2012-10-04T14:00:00", "2012-10-04T15:00:00", "2012-10-04T16:00:00", "2012-10-04T17:00:00", "2012-10-04T18:00:00", "2012-10-04T19:00:00", "2012-10-04T20:00:00", "2012-10-04T21:00:00", "2012-10-04T22:00:00", "2012-10-04T23:00:00", "2012-10-05T00:00:00", "2012-10-05T01:00:00", "2012-10-05T02:00:00", "2012-10-05T03:00:00", "2012-10-05T04:00:00", "2012-10-05T05:00:00", "2012-10-05T06:00:00", "2012-10-05T07:00:00", "2012-10-05T08:00:00", "2012-10-05T09:00:00", "2012-10-05T10:00:00", "2012-10-05T11:00:00", "2012-10-05T12:00:00", "2012-10-05T13:00:00", "2012-10-05T14:00:00", "2012-10-05T15:00:00", "2012-10-05T16:00:00", "2012-10-05T17:00:00", "2012-10-05T18:00:00", "2012-10-05T19:00:00", "2012-10-05T20:00:00", "2012-10-05T21:00:00", "2012-10-05T22:00:00", "2012-10-05T23:00:00", "2012-10-06T00:00:00", "2012-10-06T01:00:00", "2012-10-06T02:00:00", "2012-10-06T03:00:00", "2012-10-06T04:00:00", "2012-10-06T05:00:00", "2012-10-06T06:00:00", "2012-10-06T07:00:00", "2012-10-06T08:00:00", "2012-10-06T09:00:00", "2012-10-06T10:00:00", "2012-10-06T11:00:00", "2012-10-06T12:00:00", "2012-10-06T13:00:00", "2012-10-06T14:00:00", "2012-10-06T15:00:00", "2012-10-06T16:00:00", "2012-10-06T17:00:00", "2012-10-06T18:00:00", "2012-10-06T19:00:00", "2012-10-06T20:00:00", "2012-10-06T21:00:00", "2012-10-06T22:00:00", "2012-10-06T23:00:00", "2012-10-07T00:00:00", "2012-10-07T01:00:00", "2012-10-07T02:00:00", "2012-10-07T03:00:00", "2012-10-07T04:00:00", "2012-10-07T05:00:00", "2012-10-07T06:00:00", "2012-10-07T07:00:00", "2012-10-07T08:00:00", "2012-10-07T09:00:00", "2012-10-07T10:00:00", "2012-10-07T11:00:00", "2012-10-07T12:00:00", "2012-10-07T13:00:00", "2012-10-07T14:00:00", "2012-10-07T15:00:00", "2012-10-07T16:00:00", "2012-10-07T17:00:00", "2012-10-07T18:00:00", "2012-10-07T19:00:00", "2012-10-07T20:00:00", "2012-10-07T21:00:00", "2012-10-07T22:00:00", "2012-10-07T23:00:00", "2012-10-08T00:00:00", "2012-10-08T01:00:00", "2012-10-08T02:00:00", "2012-10-08T03:00:00", "2012-10-08T04:00:00", "2012-10-08T05:00:00", "2012-10-08T06:00:00", "2012-10-08T07:00:00", "2 ...

# %%
model = AR(df['Observed']).fit()
df['AR'] = model.predict()

# %%
df.set_index('Date')[['Observed', 'AR']].plot(figsize=(20,10))

# %%
model = ARMA(df['Observed'], order=(0,1)).fit()
df['MA'] = model.predict()

# %%
df.set_index('Date')[['Observed', 'AR', 'MA']].plot(figsize=(20,10))

# %%
print(model.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               Observed   No. Observations:                45099
# Model:                     ARMA(0, 1)   Log Likelihood             -124159.975
# Method:                       css-mle   S.D. of innovations              3.797
# Date:                Thu, 29 Oct 2020   AIC                         248325.949
# Time:                        14:41:28   BIC                         248352.099
# Sample:                             0   HQIC                        248334.180
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            290.8458      0.033   8873.646      0.000     290.782     290.910
# ma.L1.Observed     0.8334      0.002    488.891      0.000       0.830       0.837
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# MA.1           -1.1999           +0.0000j            1.1999            0.5000
# -----------------------------------------------------------------------------

# %%
model = ARMA(df['Observed'], order=(1,1)).fit()
df['ARMA'] = model.predict()

# %%
df.set_index('Date')[['Observed', 'ARMA']].plot(figsize=(20,10))

# %%
print(model.summary())
# Out:
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               Observed   No. Observations:                45099
# Model:                     ARMA(1, 1)   Log Likelihood              -84313.740
# Method:                       css-mle   S.D. of innovations              1.569
# Date:                Thu, 29 Oct 2020   AIC                         168635.480
# Time:                        14:47:12   BIC                         168670.346
# Sample:                             0   HQIC                        168646.454
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const            290.8484      0.212   1372.569      0.000     290.433     291.264
# ar.L1.Observed     0.9593      0.001    708.346      0.000       0.957       0.962
# ma.L1.Observed     0.1670      0.004     43.726      0.000       0.160       0.175
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.0424           +0.0000j            1.0424            0.0000
# MA.1           -5.9871           +0.0000j            5.9871            0.5000
# -----------------------------------------------------------------------------

# %%
model = ARIMA(df['Observed'], order=(1,1,1)).fit()
df['ARIMA'] = model.predict(typ='levels')

# %%
print(model.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.Observed   No. Observations:                45098
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -82579.656
# Method:                       css-mle   S.D. of innovations              1.510
# Date:                Thu, 29 Oct 2020   AIC                         165167.312
# Time:                        15:04:16   BIC                         165202.179
# Sample:                             1   HQIC                        165178.287
#
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const             6.179e-05      0.014      0.004      0.997      -0.028       0.028
# ar.L1.D.Observed     0.7541      0.005    151.741      0.000       0.744       0.764
# ma.L1.D.Observed    -0.5042      0.006    -90.211      0.000      -0.515      -0.493
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3261           +0.0000j            1.3261            0.0000
# MA.1            1.9832           +0.0000j            1.9832            0.0000
# -----------------------------------------------------------------------------

# %%
df[['Observed','ARIMA']].plot(figsize=(20,10))

# %%
model = SARIMAX(df['Observed'], order=(1,1,1), seasonal_order=(1,1,1,1)).fit()
df['SARIMA'] = model.predict()

# %%
df.iloc[10:][['Observed','SARIMA']].plot()

# %%
model = SARIMAX(df['Observed'], exog=df['Humidity'], order=(1,1,1), seasonal_order=(0,0,0,0)).fit()
df['SARIMAX'] = model.predict()

# %%
df.iloc[10:][['Observed','SARIMA', 'SARIMAX']].plot()

# %% [markdown]
# # using non-stationary data

# %%
aapl = pd.read_csv('/content/drive/My Drive/DSI Month 4/Week 12/Datasets/AAPL.csv')

# %%
aapl = aapl[['Date', 'Close']]

# %%
aapl['Close'].plot(figsize=(20,10))

# %%
# aapl['diff'] = aapl['Close'].diff()
# aapl['Close'] - aapl['Close'].shift()
# aapl['diff'].plot(figsize=(20,10))
# aapl.head()
# aapl['Close'].pct_change().plot(figsize=(20,10))
# Out:
# 0          NaN
# 1      -1.0222
# 2      -0.7178
# 3      -0.2300
# 4      -0.8758
#          ...
# 2512    1.3800
# 2513    0.1400
# 2514   -0.3100
# 2515    3.9100
# 2516    1.4900
# Name: Close, Length: 2517, dtype: float64

# %%
aapl['diff_2'] = aapl['diff'].diff()
aapl['diff'].plot()

# %%
model = ARIMA(aapl['Close'], order=(1,1,1)).fit()
predictions = model.predict(typ='levels')

# %%
predictions.plot(figsize=(20,10))

# %% [markdown]
# # Afternoon Lecture: Time Series Forecasting

# %%
import statsmodels.api as sm

# %%
data = pd.read_csv('https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/Data%20Sets%20Time%20Series%20Analysis/Time%20Series%20-%20Day%204/AMZN_data.csv')
data['date'] = pd.to_datetime(data['date'])
data.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Name']

# %%
# holdout data for evaluation purposes
train = data.iloc[:-30]
test = data.iloc[-30:]

# %%
ilinechart(data, 'Date', 'Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="608efc7d-13c1-450f-a282-573c3172064d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("608efc7d-13c1-450f-a282-573c3172064d")) {
#                     Plotly.newPlot(
#                         '608efc7d-13c1-450f-a282-573c3172064d',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Date=%{x}<br>Close=%{y}", "legendgroup": "", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "", "showlegend": false, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "2013-04-23T00:00:00", "2013-04-24T00:00:00", "2013-04-25T00:00:00", "2013-04-26T00:00:00", "2013-04-29T00:00:00", "2013-04-30T00:00:00", "2013-05-01T00:00:00", "2013-05-02T00:00:00", "2013-05-03T00:00:00", "2013-05-06T00:00:00", "2013-05-07T00:00:00", "2013-05-08T00:00:00", "2013-05-09T00:00:00", "2013-05-10T00:00:00", "2013-05-13T00:00:00", "2013-05-14T00:00:00", "2013-05-15T00:00:00", "2013-05-16T00:00:00", "2013-05-17T00:00:00", "2013-05-20T00:00:00", "2013-05-21T00:00:00", "2013-05-22T00:00:00", "2013-05-23T00:00:00", "2013-05-24T00:00:00", "2013-05-28T00:00:00", "2013-05-29T00:00:00", "2013-05-30T00:00:00", "2013-05-31T00:00:00", "2013-06-03T00:00:00", "2013-06-04T00:00:00", "2013-06-05T00:00:00", "2013-06-06T00:00:00", "2013-06-07T00:00:00", "2013-06-10T00:00:00", "2013-06-11T00:00:00", "2013-06-12T00:00:00", "2013-06-13T00:00:00", "2013-06-14T00:00:00", "2013-06-17T00:00:00", "2013-06-18T00:00:00", "2013-06-19T00:00:00", "2013-06-20T00:00:00", "2013-06-21T00:00:00", "2013-06-24T00:00:00", "2013-06-25T00:00:00", "2013-06-26T00:00:00", "2013-06-27T00:00:00", "2013-06-28T00:00:00", "2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013-09-30T00:00:00", "2013-10-01T00:00:00", "2013 ...

# %%
series = data[['Date', 'Close']].set_index('Date')
decomposition = sm.tsa.seasonal_decompose(series, model='additive', freq=252)
# Observed = Trend + Seasonality + Residuals(noise)

# components
trend = decomposition.trend.reset_index()
seasonality = decomposition.seasonal.reset_index()
residuals = decomposition.resid.reset_index()

merged = series.merge(trend, on='Date')
merged = merged.merge(seasonality, on='Date')
merged = merged.merge(residuals, on='Date')

merged.columns = ['Date', 'Observed', 'Trend', 'Seasonality', 'Residuals']

# %%
merged.set_index('Date').plot(figsize=(20,10))

# %%
merged['T+S'] = merged['Trend'] + merged['Seasonality']
merged['Total'] = merged['Trend'] + merged['Seasonality'] + merged['Residuals']

# %%
merged.set_index('Date').plot(figsize=(20,10))

# %%
melted = pd.melt(merged, id_vars='Date', value_vars=['Observed', 'Trend', 'Seasonality', 'Residuals', 'T+S', 'Total'])
melted.head()
# Out:
#         Date  variable   value
# 0 2013-02-08  Observed  261.95
# 1 2013-02-11  Observed  257.21
# 2 2013-02-12  Observed  258.70
# 3 2013-02-13  Observed  269.47
# 4 2013-02-14  Observed  269.24

# %%
ilinechart(melted, 'Date', 'value', groups='variable')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c4aebc92-7380-4911-afc4-be4b27283ea6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c4aebc92-7380-4911-afc4-be4b27283ea6")) {
#                     Plotly.newPlot(
#                         'c4aebc92-7380-4911-afc4-be4b27283ea6',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "variable=Observed<br>Date=%{x}<br>value=%{y}", "legendgroup": "variable=Observed", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "variable=Observed", "showlegend": true, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "2013-04-23T00:00:00", "2013-04-24T00:00:00", "2013-04-25T00:00:00", "2013-04-26T00:00:00", "2013-04-29T00:00:00", "2013-04-30T00:00:00", "2013-05-01T00:00:00", "2013-05-02T00:00:00", "2013-05-03T00:00:00", "2013-05-06T00:00:00", "2013-05-07T00:00:00", "2013-05-08T00:00:00", "2013-05-09T00:00:00", "2013-05-10T00:00:00", "2013-05-13T00:00:00", "2013-05-14T00:00:00", "2013-05-15T00:00:00", "2013-05-16T00:00:00", "2013-05-17T00:00:00", "2013-05-20T00:00:00", "2013-05-21T00:00:00", "2013-05-22T00:00:00", "2013-05-23T00:00:00", "2013-05-24T00:00:00", "2013-05-28T00:00:00", "2013-05-29T00:00:00", "2013-05-30T00:00:00", "2013-05-31T00:00:00", "2013-06-03T00:00:00", "2013-06-04T00:00:00", "2013-06-05T00:00:00", "2013-06-06T00:00:00", "2013-06-07T00:00:00", "2013-06-10T00:00:00", "2013-06-11T00:00:00", "2013-06-12T00:00:00", "2013-06-13T00:00:00", "2013-06-14T00:00:00", "2013-06-17T00:00:00", "2013-06-18T00:00:00", "2013-06-19T00:00:00", "2013-06-20T00:00:00", "2013-06-21T00:00:00", "2013-06-24T00:00:00", "2013-06-25T00:00:00", "2013-06-26T00:00:00", "2013-06-27T00:00:00", "2013-06-28T00:00:00", "2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00 ...

# %%
model = sm.tsa.ExponentialSmoothing(data['Close']).fit()
single_exp = model.forecast(30)

# %%
model = sm.tsa.ExponentialSmoothing(data['Close'], trend='additive').fit()
double_exp = model.forecast(30)

# %%
model = sm.tsa.ExponentialSmoothing(data['Close'], 
                                    trend='additive', 
                                    seasonal='additive', 
                                    seasonal_periods=4).fit()
triple_exp = model.forecast(30)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/holtwinters.py:712: ConvergenceWarning:
#
# Optimization failed to converge. Check mle_retvals.

# %%
def forecast(data, field, model, periods):
    model_results = model.forecast(periods)[0]
    current_value = data[field].iloc[-1]
    forecasts = []
    
    for result in model_results:
        forecast = current_value + result
        forecasts.append(forecast)
        current_value = forecast
    
    forecasts = pd.Series(forecasts)
    forecasts.index = [x + periods 
                       for x in list(data[field].tail(periods).index)]
    
    return forecasts

# %%
data['Shift'] = data['Close'].shift().fillna(method='bfill')
data['Diff'] = data['Close'] - data['Shift']

# %%
data.head()
# Out:
#         Date    Open    High      Low   Close   Volume  Name   Shift   Diff
# 0 2013-02-08  261.40  265.25  260.555  261.95  3879078  AMZN  261.95   0.00
# 1 2013-02-11  263.20  263.25  256.600  257.21  3403403  AMZN  261.95  -4.74
# 2 2013-02-12  259.19  260.16  257.000  258.70  2938660  AMZN  257.21   1.49
# 3 2013-02-13  261.53  269.96  260.300  269.47  5292996  AMZN  258.70  10.77
# 4 2013-02-14  267.37  270.65  265.400  269.24  3462780  AMZN  269.47  -0.23

# %%
model = ARMA(data['Diff'], order=(2,1)).fit()
arma_forecasts = forecast(data, 'Close', model, 30)
arma_forecasts
# Out:
# 1259    1421.330867
# 1260    1419.611896
# 1261    1421.839949
# 1262    1422.076825
# 1263    1423.347968
# 1264    1424.084126
# 1265    1425.097174
# 1266    1425.966926
# 1267    1426.910837
# 1268    1427.816369
# 1269    1428.741763
# 1270    1429.656878
# 1271    1430.577313
# 1272    1431.494995
# 1273    1432.414101
# 1274    1433.332470
# 1275    1434.251221
# 1276    1435.169774
# 1277    1436.088429
# 1278    1437.007032
# 1279    1437.925662
# 1280    1438.844277
# 1281    1439.762900
# 1282    1440.681520
# 1283    1441.600141
# 1284    1442.518761
# 1285    1443.437382
# 1286    1444.356002
# 1287    1445.274623
# 1288    1446.193243
# dtype: float64

# %%
model = ARIMA(data['Diff'], order=(1,1,1)).fit()
arima_forecasts = forecast(data, 'Close', model, 30)
arima_forecasts
# Out:
# 1259    1419.337509
# 1260    1421.528503
# 1261    1423.726235
# 1262    1425.925898
# 1263    1428.127553
# 1264    1430.331201
# 1265    1432.536840
# 1266    1434.744472
# 1267    1436.954096
# 1268    1439.165711
# 1269    1441.379319
# 1270    1443.594918
# 1271    1445.812510
# 1272    1448.032094
# 1273    1450.253669
# 1274    1452.477237
# 1275    1454.702796
# 1276    1456.930348
# 1277    1459.159892
# 1278    1461.391427
# 1279    1463.624955
# 1280    1465.860474
# 1281    1468.097986
# 1282    1470.337490
# 1283    1472.578985
# 1284    1474.822473
# 1285    1477.067952
# 1286    1479.315424
# 1287    1481.564888
# 1288    1483.816343
# dtype: float64

# %%
model = SARIMAX(data['Close'], order=(2,1,1), seasonal_order=(1,1,1,1)).fit()
sarima_forecasts = model.forecast(30)
sarima_forecasts
# Out:
# 1259    1422.466897
# 1260    1423.417623
# 1261    1426.675486
# 1262    1429.528282
# 1263    1432.454299
# 1264    1435.287584
# 1265    1438.085368
# 1266    1440.853048
# 1267    1443.605133
# 1268    1446.348064
# 1269    1449.086202
# 1270    1451.821788
# 1271    1454.556065
# 1272    1457.289672
# 1273    1460.022943
# 1274    1462.756046
# 1275    1465.489065
# 1276    1468.222042
# 1277    1470.955000
# 1278    1473.687948
# 1279    1476.420891
# 1280    1479.153832
# 1281    1481.886772
# 1282    1484.619711
# 1283    1487.352650
# 1284    1490.085589
# 1285    1492.818527
# 1286    1495.551466
# 1287    1498.284405
# 1288    1501.017343
# dtype: float64

# %%
series = data[['Date', 'Close']]

# %%
series.columns = ['ds', 'y']
series
# Out:
#              ds        y
# 0    2013-02-08   261.95
# 1    2013-02-11   257.21
# 2    2013-02-12   258.70
# 3    2013-02-13   269.47
# 4    2013-02-14   269.24
# ...         ...      ...
# 1254 2018-02-01  1390.00
# 1255 2018-02-02  1429.95
# 1256 2018-02-05  1390.00
# 1257 2018-02-06  1442.84
# 1258 2018-02-07  1416.78
#
# [1259 rows x 2 columns]

# %%
from fbprophet import Prophet

model = Prophet()
model.fit(series)

# creates future dates for forecasting
future = model.make_future_dataframe(30)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
series.tail()
# Out:
#              ds        y
# 1254 2018-02-01  1390.00
# 1255 2018-02-02  1429.95
# 1256 2018-02-05  1390.00
# 1257 2018-02-06  1442.84
# 1258 2018-02-07  1416.78

# %%
future.tail(30)
# Out:
#              ds
# 1259 2018-02-08
# 1260 2018-02-09
# 1261 2018-02-10
# 1262 2018-02-11
# 1263 2018-02-12
# 1264 2018-02-13
# 1265 2018-02-14
# 1266 2018-02-15
# 1267 2018-02-16
# 1268 2018-02-17
# 1269 2018-02-18
# 1270 2018-02-19
# 1271 2018-02-20
# 1272 2018-02-21
# 1273 2018-02-22
# 1274 2018-02-23
# 1275 2018-02-24
# 1276 2018-02-25
# 1277 2018-02-26
# 1278 2018-02-27
# 1279 2018-02-28
# 1280 2018-03-01
# 1281 2018-03-02
# 1282 2018-03-03
# 1283 2018-03-04
# 1284 2018-03-05
# 1285 2018-03-06
# 1286 2018-03-07
# 1287 2018-03-08
# 1288 2018-03-09

# %%
results = model.predict(future)
results.head()
# Out:
#           ds       trend  ...  multiplicative_terms_upper        yhat
# 0 2013-02-08  217.522284  ...                         0.0  254.655678
# 1 2013-02-11  218.506266  ...                         0.0  253.385216
# 2 2013-02-12  218.834260  ...                         0.0  253.228631
# 3 2013-02-13  219.162254  ...                         0.0  253.053499
# 4 2013-02-14  219.490248  ...                         0.0  252.750585
#
# [5 rows x 19 columns]

# %%
results.tail(30)
# Out:
#              ds        trend  ...  multiplicative_terms_upper         yhat
# 1259 2018-02-08  1275.659831  ...                         0.0  1312.664848
# 1260 2018-02-09  1277.005720  ...                         0.0  1313.501006
# 1261 2018-02-10  1278.351608  ...                         0.0  1339.494327
# 1262 2018-02-11  1279.697497  ...                         0.0  1340.151995
# 1263 2018-02-12  1281.043385  ...                         0.0  1315.500088
# 1264 2018-02-13  1282.389274  ...                         0.0  1316.454655
# 1265 2018-02-14  1283.735163  ...                         0.0  1317.396726
# 1266 2018-02-15  1285.081051  ...                         0.0  1318.214110
# 1267 2018-02-16  1286.426940  ...                         0.0  1319.858978
# 1268 2018-02-17  1287.772828  ...                         0.0  1346.718846
# 1269 2018-02-18  1289.118717  ...                         0.0  1348.274795
# 1270 2018-02-19  1290.464605  ...                         0.0  1324.526494
# 1271 2018-02-20  1291.810494  ...                         0.0  1326.363929
# 1272 2018-02-21  1293.156383  ...                         0.0  1328.143065
# 1273 2018-02-22  1294.502271  ...                         0.0  1329.728262
# 1274 2018-02-23  1295.848160  ...                         0.0  1332.050417
# 1275 2018-02-24  1297.194048  ...                         0.0  1359.478461
# 1276 2018-02-25  1298.539937  ...                         0.0  1361.478004
# 1277 2018-02-26  1299.885826  ...                         0.0  1338.036699
# 1278 2018-02-27  1301.231714  ...                         0.0  1340.036232
# 1279 2018-02-28  1302.577603  ...                         0.0  1341.828131
# 1280 2018-03-01  1303.923491  ...                         0.0  1343.276234
# 1281 2018-03-02  1305.269380  ...                         0.0  1345.314785
# 1282 2018-03-03  1306.615268  ...                         0.0  1372.319779
# 1283 2018-03-04  1307.961157  ...                         0.0  1373.767368
# 1284 2018-03-05  1309.307046  ...                         0.0  1349.658899
# 1285 2018-03-06  1310.652934  ...                         0.0  1350.892500
# 1286 2018-03-07  1311.998823  ...                         0.0  1351.838419
# 1287 2018-03-08  1313.344711  ...                         0.0  1352.380979
# 1288 2018-03-09  1314.690600  ...                         0.0  1353.476117
#
# [30 rows x 19 columns]

# %%
prophet_forecasts = results.iloc[-30:]['yhat']
prophet_forecasts
# Out:
# 1259    1312.664848
# 1260    1313.501006
# 1261    1339.494327
# 1262    1340.151995
# 1263    1315.500088
# 1264    1316.454655
# 1265    1317.396726
# 1266    1318.214110
# 1267    1319.858978
# 1268    1346.718846
# 1269    1348.274795
# 1270    1324.526494
# 1271    1326.363929
# 1272    1328.143065
# 1273    1329.728262
# 1274    1332.050417
# 1275    1359.478461
# 1276    1361.478004
# 1277    1338.036699
# 1278    1340.036232
# 1279    1341.828131
# 1280    1343.276234
# 1281    1345.314785
# 1282    1372.319779
# 1283    1373.767368
# 1284    1349.658899
# 1285    1350.892500
# 1286    1351.838419
# 1287    1352.380979
# 1288    1353.476117
# Name: yhat, dtype: float64

# %%
future_dates = pd.DataFrame({'Date': pd.date_range(start=data.Date.iloc[-1], periods=31, 
                                                   freq='D', closed='right')})

# %%
# adds in the 30 extra rows of dates
fcast_df = pd.concat([pd.DataFrame(data['Date']), future_dates], ignore_index=True)
fcast_df
# Out:
#            Date
# 0    2013-02-08
# 1    2013-02-11
# 2    2013-02-12
# 3    2013-02-13
# 4    2013-02-14
# ...         ...
# 1284 2018-03-05
# 1285 2018-03-06
# 1286 2018-03-07
# 1287 2018-03-08
# 1288 2018-03-09
#
# [1289 rows x 1 columns]

# %%
fcast_df = fcast_df.merge(data[['Date', 'Close']], on='Date', how='left')

# %%
fcast_df['Double_Exp_Smooth'] = double_exp
fcast_df['Triple_Exp_Smooth'] = triple_exp
fcast_df['ARMA'] = arma_forecasts
fcast_df['ARIMA'] = arima_forecasts
fcast_df['SARIMA'] = sarima_forecasts
fcast_df['Prophet'] = prophet_forecasts

# %%
fcast_df.tail(30)
# Out:
#            Date  Close  ...       SARIMA      Prophet
# 1259 2018-02-08    NaN  ...  1422.466897  1312.664848
# 1260 2018-02-09    NaN  ...  1423.417623  1313.501006
# 1261 2018-02-10    NaN  ...  1426.675486  1339.494327
# 1262 2018-02-11    NaN  ...  1429.528282  1340.151995
# 1263 2018-02-12    NaN  ...  1432.454299  1315.500088
# 1264 2018-02-13    NaN  ...  1435.287584  1316.454655
# 1265 2018-02-14    NaN  ...  1438.085368  1317.396726
# 1266 2018-02-15    NaN  ...  1440.853048  1318.214110
# 1267 2018-02-16    NaN  ...  1443.605133  1319.858978
# 1268 2018-02-17    NaN  ...  1446.348064  1346.718846
# 1269 2018-02-18    NaN  ...  1449.086202  1348.274795
# 1270 2018-02-19    NaN  ...  1451.821788  1324.526494
# 1271 2018-02-20    NaN  ...  1454.556065  1326.363929
# 1272 2018-02-21    NaN  ...  1457.289672  1328.143065
# 1273 2018-02-22    NaN  ...  1460.022943  1329.728262
# 1274 2018-02-23    NaN  ...  1462.756046  1332.050417
# 1275 2018-02-24    NaN  ...  1465.489065  1359.478461
# 1276 2018-02-25    NaN  ...  1468.222042  1361.478004
# 1277 2018-02-26    NaN  ...  1470.955000  1338.036699
# 1278 2018-02-27    NaN  ...  1473.687948  1340.036232
# 1279 2018-02-28    NaN  ...  1476.420891  1341.828131
# 1280 2018-03-01    NaN  ...  1479.153832  1343.276234
# 1281 2018-03-02    NaN  ...  1481.886772  1345.314785
# 1282 2018-03-03    NaN  ...  1484.619711  1372.319779
# 1283 2018-03-04    NaN  ...  1487.352650  1373.767368
# 1284 2018-03-05    NaN  ...  1490.085589  1349.658899
# 1285 2018-03-06    NaN  ...  1492.818527  1350.892500
# 1286 2018-03-07    NaN  ...  1495.551466  1351.838419
# 1287 2018-03-08    NaN  ...  1498.284405  1352.380979
# 1288 2018-03-09    NaN  ...  1501.017343  1353.476117
#
# [30 rows x 8 columns]

# %%
melted = pd.melt(fcast_df, id_vars='Date', var_name='Variable', value_name='Value', 
                 value_vars=list(fcast_df.columns)[1:])

ilinechart(melted, 'Date', 'Value', groups='Variable', 
                title='Forecast Comparison')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9dd31aa7-3795-49bc-977d-fc6b9d0d23a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9dd31aa7-3795-49bc-977d-fc6b9d0d23a5")) {
#                     Plotly.newPlot(
#                         '9dd31aa7-3795-49bc-977d-fc6b9d0d23a5',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Variable=Close<br>Date=%{x}<br>Value=%{y}", "legendgroup": "Variable=Close", "line": {"color": "#1F77B4", "dash": "solid"}, "mode": "lines", "name": "Variable=Close", "showlegend": true, "type": "scattergl", "x": ["2013-02-08T00:00:00", "2013-02-11T00:00:00", "2013-02-12T00:00:00", "2013-02-13T00:00:00", "2013-02-14T00:00:00", "2013-02-15T00:00:00", "2013-02-19T00:00:00", "2013-02-20T00:00:00", "2013-02-21T00:00:00", "2013-02-22T00:00:00", "2013-02-25T00:00:00", "2013-02-26T00:00:00", "2013-02-27T00:00:00", "2013-02-28T00:00:00", "2013-03-01T00:00:00", "2013-03-04T00:00:00", "2013-03-05T00:00:00", "2013-03-06T00:00:00", "2013-03-07T00:00:00", "2013-03-08T00:00:00", "2013-03-11T00:00:00", "2013-03-12T00:00:00", "2013-03-13T00:00:00", "2013-03-14T00:00:00", "2013-03-15T00:00:00", "2013-03-18T00:00:00", "2013-03-19T00:00:00", "2013-03-20T00:00:00", "2013-03-21T00:00:00", "2013-03-22T00:00:00", "2013-03-25T00:00:00", "2013-03-26T00:00:00", "2013-03-27T00:00:00", "2013-03-28T00:00:00", "2013-04-01T00:00:00", "2013-04-02T00:00:00", "2013-04-03T00:00:00", "2013-04-04T00:00:00", "2013-04-05T00:00:00", "2013-04-08T00:00:00", "2013-04-09T00:00:00", "2013-04-10T00:00:00", "2013-04-11T00:00:00", "2013-04-12T00:00:00", "2013-04-15T00:00:00", "2013-04-16T00:00:00", "2013-04-17T00:00:00", "2013-04-18T00:00:00", "2013-04-19T00:00:00", "2013-04-22T00:00:00", "2013-04-23T00:00:00", "2013-04-24T00:00:00", "2013-04-25T00:00:00", "2013-04-26T00:00:00", "2013-04-29T00:00:00", "2013-04-30T00:00:00", "2013-05-01T00:00:00", "2013-05-02T00:00:00", "2013-05-03T00:00:00", "2013-05-06T00:00:00", "2013-05-07T00:00:00", "2013-05-08T00:00:00", "2013-05-09T00:00:00", "2013-05-10T00:00:00", "2013-05-13T00:00:00", "2013-05-14T00:00:00", "2013-05-15T00:00:00", "2013-05-16T00:00:00", "2013-05-17T00:00:00", "2013-05-20T00:00:00", "2013-05-21T00:00:00", "2013-05-22T00:00:00", "2013-05-23T00:00:00", "2013-05-24T00:00:00", "2013-05-28T00:00:00", "2013-05-29T00:00:00", "2013-05-30T00:00:00", "2013-05-31T00:00:00", "2013-06-03T00:00:00", "2013-06-04T00:00:00", "2013-06-05T00:00:00", "2013-06-06T00:00:00", "2013-06-07T00:00:00", "2013-06-10T00:00:00", "2013-06-11T00:00:00", "2013-06-12T00:00:00", "2013-06-13T00:00:00", "2013-06-14T00:00:00", "2013-06-17T00:00:00", "2013-06-18T00:00:00", "2013-06-19T00:00:00", "2013-06-20T00:00:00", "2013-06-21T00:00:00", "2013-06-24T00:00:00", "2013-06-25T00:00:00", "2013-06-26T00:00:00", "2013-06-27T00:00:00", "2013-06-28T00:00:00", "2013-07-01T00:00:00", "2013-07-02T00:00:00", "2013-07-03T00:00:00", "2013-07-05T00:00:00", "2013-07-08T00:00:00", "2013-07-09T00:00:00", "2013-07-10T00:00:00", "2013-07-11T00:00:00", "2013-07-12T00:00:00", "2013-07-15T00:00:00", "2013-07-16T00:00:00", "2013-07-17T00:00:00", "2013-07-18T00:00:00", "2013-07-19T00:00:00", "2013-07-22T00:00:00", "2013-07-23T00:00:00", "2013-07-24T00:00:00", "2013-07-25T00:00:00", "2013-07-26T00:00:00", "2013-07-29T00:00:00", "2013-07-30T00:00:00", "2013-07-31T00:00:00", "2013-08-01T00:00:00", "2013-08-02T00:00:00", "2013-08-05T00:00:00", "2013-08-06T00:00:00", "2013-08-07T00:00:00", "2013-08-08T00:00:00", "2013-08-09T00:00:00", "2013-08-12T00:00:00", "2013-08-13T00:00:00", "2013-08-14T00:00:00", "2013-08-15T00:00:00", "2013-08-16T00:00:00", "2013-08-19T00:00:00", "2013-08-20T00:00:00", "2013-08-21T00:00:00", "2013-08-22T00:00:00", "2013-08-23T00:00:00", "2013-08-26T00:00:00", "2013-08-27T00:00:00", "2013-08-28T00:00:00", "2013-08-29T00:00:00", "2013-08-30T00:00:00", "2013-09-03T00:00:00", "2013-09-04T00:00:00", "2013-09-05T00:00:00", "2013-09-06T00:00:00", "2013-09-09T00:00:00", "2013-09-10T00:00:00", "2013-09-11T00:00:00", "2013-09-12T00:00:00", "2013-09-13T00:00:00", "2013-09-16T00:00:00", "2013-09-17T00:00:00", "2013-09-18T00:00:00", "2013-09-19T00:00:00", "2013-09-20T00:00:00", "2013-09-23T00:00:00", "2013-09-24T00:00:00", "2013-09-25T00:00:00", "2013-09-26T00:00:00", "2013-09-27T00:00:00", "2013- ...
