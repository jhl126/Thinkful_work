# %% [markdown]
# Day 24 Lecture 1 Assignment
# In this assignment, we will build our first logistic regression model on numeric data. We will use the FIFA soccer ratings dataset loaded below and analyze the model generated for this dataset.

# %%
# %reload_ext nb_black
import pandas as pd
import numpy as np

import statsmodels.api as sm
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

from mlxtend.plotting import plot_decision_regions
import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def remove_correlated_features(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if (corr_matrix.iloc[i, j] >= threshold) and (
                corr_matrix.columns[j] not in col_corr
            ):
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
                if colname in dataset.columns:
                    print(f"Deleted {colname} from dataset.")
                    del dataset[colname]

    return dataset

# %%
soccer_data = pd.read_csv(
    "https://tf-assets-prod.s3.amazonaws.com/tf-curric/data-science/fifa_ratings.csv"
)

# %%
soccer_data.head()
# Out:
#        ID               Name  Overall  Crossing  Finishing  HeadingAccuracy  \
# 0  158023           L. Messi       94        84         95               70
# 1   20801  Cristiano Ronaldo       94        84         94               89
# 2  190871          Neymar Jr       92        79         87               62
# 3  192985       K. De Bruyne       91        93         82               55
# 4  183277          E. Hazard       91        81         84               61
#
#    ShortPassing  Volleys  Dribbling  Curve  ...  LongShots  Aggression  \
# 0            90       86         97     93  ...         94          48
# 1            81       87         88     81  ...         93          63
# 2            84       84         96     88  ...         82          56
# 3            92       82         86     85  ...         91          76
# 4            89       80         95     83  ...         80          54
#
#    Interceptions  Positioning  Vision  Penalties  Composure  Marking  \
# 0             22           94      94         75         96       33
# 1             29           95      82         85         95       28
# 2             36           89      87         81         94       27
# 3             61           87      94         79         88       68
# 4             41           87      89         86         91       34
#
#    StandingTackle  SlidingTackle
# 0              28             26
# 1              31             23
# 2              24             33
# 3              58             51
# 4              27             22
#
# [5 rows x 32 columns]

# %% [markdown]
# Our response for our logistic regression model is going to be a binary label, "Elite" or "Not Elite", corresponding to whether or not the player has an overall rating greater than or equal to 75. This corresponds to the top 10% or so of soccer players in the data set. Create the response column.

# %%
soccer_data["Is_Elite"] = soccer_data["Overall"] >= 75
soccer_data
# Out:
#            ID                Name  Overall  Crossing  Finishing  \
# 0      158023            L. Messi       94        84         95
# 1       20801   Cristiano Ronaldo       94        84         94
# 2      190871           Neymar Jr       92        79         87
# 3      192985        K. De Bruyne       91        93         82
# 4      183277           E. Hazard       91        81         84
# ...       ...                 ...      ...       ...        ...
# 16117  238813        J. Lundstram       47        34         38
# 16118  243165  N. Christoffersson       47        23         52
# 16119  241638           B. Worman       47        25         40
# 16120  246268      D. Walker-Rice       47        44         50
# 16121  246269           G. Nugent       46        41         34
#
#        HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  ...  \
# 0                   70            90       86         97     93  ...
# 1                   89            81       87         88     81  ...
# 2                   62            84       84         96     88  ...
# 3                   55            92       82         86     85  ...
# 4                   61            89       80         95     83  ...
# ...                ...           ...      ...        ...    ...  ...
# 16117               40            49       25         42     30  ...
# 16118               52            43       36         39     32  ...
# 16119               46            38       38         45     38  ...
# 16120               39            42       40         51     34  ...
# 16121               46            48       30         43     40  ...
#
#        Aggression  Interceptions  Positioning  Vision  Penalties  Composure  \
# 0              48             22           94      94         75         96
# 1              63             29           95      82         85         95
# 2              56             36           89      87         81         94
# 3              76             61           87      94         79         88
# 4              54             41           87      89         86         91
# ...           ...            ...          ...     ...        ...        ...
# 16117          46             46           39      52         43         45
# 16118          47             16           46      33         43         42
# 16119          32             15           48      43         55         41
# 16120          33             22           44      47         50         46
# 16121          56             42           34      49         33         43
#
#        Marking  StandingTackle  SlidingTackle  Is_Elite
# 0           33              28             26      True
# 1           28              31             23      True
# 2           27              24             33      True
# 3           68              58             51      True
# 4           34              27             22      True
# ...        ...             ...            ...       ...
# 16117       40              48             47     False
# 16118       22              15             19     False
# 16119       32              13             11     False
# 16120       20              25             27     False
# 16121       40              43             50     False
#
# [16122 rows x 33 columns]

# %% [markdown]
# Address potential collinearity issues by removing the appropriate features. There is no universally agreed upon technique for doing so, so feel free to use any reasonable method. We have provided the convenience function *remove_correlated_features* at the top as one way of doing so, and we use a threshold of 0.9 for that function to reduce correlation among features.

# %%
remove_correlated_features(soccer_data, 0.9)
# Out:
# Deleted StandingTackle from dataset.
# Deleted SlidingTackle from dataset.
#            ID                Name  Overall  Crossing  Finishing  \
# 0      158023            L. Messi       94        84         95
# 1       20801   Cristiano Ronaldo       94        84         94
# 2      190871           Neymar Jr       92        79         87
# 3      192985        K. De Bruyne       91        93         82
# 4      183277           E. Hazard       91        81         84
# ...       ...                 ...      ...       ...        ...
# 16117  238813        J. Lundstram       47        34         38
# 16118  243165  N. Christoffersson       47        23         52
# 16119  241638           B. Worman       47        25         40
# 16120  246268      D. Walker-Rice       47        44         50
# 16121  246269           G. Nugent       46        41         34
#
#        HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  ...  \
# 0                   70            90       86         97     93  ...
# 1                   89            81       87         88     81  ...
# 2                   62            84       84         96     88  ...
# 3                   55            92       82         86     85  ...
# 4                   61            89       80         95     83  ...
# ...                ...           ...      ...        ...    ...  ...
# 16117               40            49       25         42     30  ...
# 16118               52            43       36         39     32  ...
# 16119               46            38       38         45     38  ...
# 16120               39            42       40         51     34  ...
# 16121               46            48       30         43     40  ...
#
#        Strength  LongShots  Aggression  Interceptions  Positioning  Vision  \
# 0            59         94          48             22           94      94
# 1            79         93          63             29           95      82
# 2            49         82          56             36           89      87
# 3            75         91          76             61           87      94
# 4            66         80          54             41           87      89
# ...         ...        ...         ...            ...          ...     ...
# 16117        47         38          46             46           39      52
# 16118        67         42          47             16           46      33
# 16119        32         45          32             15           48      43
# 16120        48         34          33             22           44      47
# 16121        60         32          56             42           34      49
#
#        Penalties  Composure  Marking  Is_Elite
# 0             75         96       33      True
# 1             85         95       28      True
# 2             81         94       27      True
# 3             79         88       68      True
# 4             86         91       34      True
# ...          ...        ...      ...       ...
# 16117         43         45       40     False
# 16118         43         42       22     False
# 16119         55         41       32     False
# 16120         50         46       20     False
# 16121         33         43       40     False
#
# [16122 rows x 31 columns]

# %% [markdown]
# Split the data into train and test, with 80% training and 20% testing. Be sure to leave out columns that would not make sense in the model, like the player ID column.

# %%
X = soccer_data.drop(columns=["ID", "Name", "Overall", "Is_Elite"])
y = soccer_data["Is_Elite"]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=27
)

# %% [markdown]
# Fit the logistic regression model using the statsmodels package and print out the coefficient summary. Which variables appear to be the most important, and what effect do they have on the probability of a player being elite?

# %% [markdown]
# # sklearn

# %%
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
model.score(X_train, y_train)
# Out:
# 0.9582848724509576

# %%
model.score(X_test, y_test)
# Out:
# 0.9556589147286821

# %%
coef_df = pd.DataFrame({"feat": X.columns, "coef": model.coef_.flatten()})
coef_df
# Out:
#                feat      coef
# 0          Crossing -0.012520
# 1         Finishing  0.024284
# 2   HeadingAccuracy  0.045465
# 3      ShortPassing  0.184808
# 4           Volleys -0.020302
# 5         Dribbling -0.004909
# 6             Curve  0.002839
# 7        FKAccuracy  0.004580
# 8       LongPassing -0.001029
# 9       BallControl  0.195123
# 10     Acceleration  0.030551
# 11      SprintSpeed  0.043055
# 12          Agility -0.008105
# 13        Reactions  0.294720
# 14          Balance -0.033128
# 15        ShotPower  0.046637
# 16          Jumping  0.008906
# 17          Stamina -0.018938
# 18         Strength  0.014390
# 19        LongShots -0.029463
# 20       Aggression  0.007865
# 21    Interceptions -0.014026
# 22      Positioning -0.053190
# 23           Vision -0.035690
# 24        Penalties -0.004817
# 25        Composure  0.114145
# 26          Marking  0.017809

# %% [markdown]
# # statsmodel

# %%
X_train_const = sm.add_constant(X_train)
X_test_const = sm.add_constant(X_test)

sm_model = sm.Logit(y_train, X_train_const).fit()
print(sm_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.104045
#          Iterations 10
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Is_Elite   No. Observations:                12897
# Model:                          Logit   Df Residuals:                    12869
# Method:                           MLE   Df Model:                           27
# Date:                Thu, 27 Aug 2020   Pseudo R-squ.:                  0.7152
# Time:                        12:01:12   Log-Likelihood:                -1341.9
# converged:                       True   LL-Null:                       -4711.0
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const             -58.1098      1.753    -33.142      0.000     -61.546     -54.673
# Crossing           -0.0125      0.006     -1.961      0.050      -0.025   -9.15e-06
# Finishing           0.0243      0.008      3.079      0.002       0.009       0.040
# HeadingAccuracy     0.0455      0.007      6.631      0.000       0.032       0.059
# ShortPassing        0.1848      0.017     10.699      0.000       0.151       0.219
# Volleys            -0.0203      0.006     -3.225      0.001      -0.033      -0.008
# Dribbling          -0.0049      0.012     -0.409      0.683      -0.029       0.019
# Curve               0.0028      0.007      0.414      0.679      -0.011       0.016
# FKAccuracy          0.0046      0.006      0.808      0.419      -0.007       0.016
# LongPassing        -0.0010      0.010     -0.108      0.914      -0.020       0.018
# BallControl         0.1952      0.018     10.840      0.000       0.160       0.231
# Acceleration        0.0306      0.011      2.831      0.005       0.009       0.052
# SprintSpeed         0.0430      0.010      4.409      0.000       0.024       0.062
# Agility            -0.0081      0.009     -0.855      0.393      -0.027       0.010
# Reactions           0.2947      0.015     20.157      0.000       0.266       0.323
# Balance            -0.0331      0.007     -4.416      0.000      -0.048      -0.018
# ShotPower           0.0466      0.009      5.415      0.000       0.030       0.064
# Jumping             0.0089      0.005      1.722      0.085      -0.001       0.019
# Stamina            -0.0189      0.006     -2.959      0.003      -0.031      -0.006
# Strength            0.0144      0.008      1.903      0.057      -0.000       0.029
# LongShots          -0.0295      0.008     -3.639      0.000      -0.045      -0.014
# Aggression          0.0079      0.006      1.405      0.160      -0.003       0.019
# Interceptions      -0.0140      0.006     -2.288      0.022      -0.026      -0.002
# Positioning        -0.0532      0.008     -6.528      0.000      -0.069      -0.037
# Vision             -0.0357      0.009     -4.101      0.000      -0.053      -0.019
# Penalties          -0.0048      0.006     -0.752      0.452      -0.017       0.008
# Composure           0.1142      0.011     10.632      0.000       0.093       0.135
# Marking             0.0178      0.006      3.143      0.002       0.007       0.029
# ===================================================================================
#
# Possibly complete quasi-separation: A fraction 0.38 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %% [markdown]
# We have yet to discuss how to evaluate the model, which will happen next week, but one intuitive way to see if our model predictions are reasonable is to plot a calibration curve. In essence, the probabilities predicted by a good model will match the observed proportions of outcomes (i.e. If we take all of the predictions around 70% made by our model, the corresponding observed outcomes should be Elite about 70% of the time).
#
# First, make predictions on the test set and join them to the corresponding true outcomes. Then, use the *calibration_curve* function in scikit learn to plot a calibration curve. What do you see?
#
# There is some helpful code for creating calibration plots at the link below:
# https://scikit-learn.org/stable/auto_examples/calibration/plot_calibration_curve.html#sphx-glr-auto-examples-calibration-plot-calibration-curve-py

# %% [markdown]
# We see that the lower predicted probabilities tend to be well calibrated - when the model predicts 20% likelihood of eliteness, for example, we tend to see about 20% in reality, which is a good sign. However, the calibration does falter quite a bit for the more confident predictions; weaker calibration at the extremes is fairly common for probabilistic models, although not always to this extent.
